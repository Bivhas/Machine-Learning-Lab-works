# %%
student = {
  "name":"Bivhas",
  "age":20,
  "faculty":"BCE"
}
print(student)
# Out:
# {'name': 'Bivhas', 'age': 20, 'faculty': 'BCE'}

# %%
d={"name":"Dinesh","age":20,"faculty":"BCE"}

# %%
d["name"]
# Out:
# 'Dinesh'

# %%
d["age"]
# Out:
# 20

# %%
d["faculty"]
# Out:
# 'BCE'

# %%
d.get("name")
# Out:
# 'Dinesh'

# %%
d["location"]="Sitapaila"
print(d)
# Out:
# {'name': 'Dinesh', 'age': 20, 'faculty': 'BCE', 'location': 'Sitapaila'}

# %%
d["name"]="Dinesh Gurung"
print(d)
# Out:
# {'name': 'Dinesh Gurung', 'age': 20, 'faculty': 'BCE', 'location': 'Sitapaila'}

# %%
del d["location"]
print(d)
# Out:
# {'name': 'Dinesh Gurung', 'age': 20, 'faculty': 'BCE'}

# %%
d.pop("age")
print(d)
# Out:
# {'name': 'Dinesh Gurung'}

# %%
d.popitem()
print(d)
# Out:
# {}

# %%
d={"name":"Razak","age":20,"faculty":"BCE"}
print(d)
# Out:
# {'name': 'Razak', 'age': 20, 'faculty': 'BCE'}

# %%
d.clear()
print(d)
# Out:
# {}

# %%
c={"name":"Sudeep","age":20,"faculty":"BCE"}
d=c.copy()
print(d)
# Out:
# {'name': 'Sudeep', 'age': 20, 'faculty': 'BCE'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'faculty'])

# %%
d.values()
# Out:
# dict_values(['Sudeep', 20, 'BCE'])

# %%
d.items()
# Out:
# dict_items([('name', 'Sudeep'), ('age', 20), ('faculty', 'BCE')])

# %%
"name" in d
# Out:
# True

# %%
"location" in d
# Out:
# False

# %%
for k in d:
  print(k)
# Out:
# name
# age
# faculty

# %%
for v in d.values():
  print(v)
# Out:
# Sudeep
# 20
# BCE

# %%
for k,v in d.items():
  print(k,v)
# Out:
# name Sudeep
# age 20
# faculty BCE

# %%
import pandas as pd

# %%
d={
    "name":["Dinesh","Bivhas","Jikmet","Sudeep","Sworup","Sangat"],
    "age":[22,20,21,25,23,32],
    "marks":[70,72,80,90,75,73]
}
df=pd.DataFrame(d)

# %%
df.head()
# Out:
#      name  age  marks
# 0  Dinesh   22     70
# 1  Bivhas   20     72
# 2  Jikmet   21     80
# 3  Sudeep   25     90
# 4  Sworup   23     75

# %%
df.tail()
# Out:
#      name  age  marks
# 1  Bivhas   20     72
# 2  Jikmet   21     80
# 3  Sudeep   25     90
# 4  Sworup   23     75
# 5  Sangat   32     73

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   marks   6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %%
df.describe()
# Out:
#              age      marks
# count   6.000000   6.000000
# mean   23.833333  76.666667
# std     4.355074   7.366591
# min    20.000000  70.000000
# 25%    21.250000  72.250000
# 50%    22.500000  74.000000
# 75%    24.500000  78.750000
# max    32.000000  90.000000

# %%
df['name']
# Out:
# 0    Dinesh
# 1    Bivhas
# 2    Jikmet
# 3    Sudeep
# 4    Sworup
# 5    Sangat
# Name: name, dtype: object

# %%
df[['name','marks']]
# Out:
#      name  marks
# 0  Dinesh     70
# 1  Bivhas     72
# 2  Jikmet     80
# 3  Sudeep     90
# 4  Sworup     75
# 5  Sangat     73

# %%
df.iloc[1]
# Out:
# name     Bivhas
# age          20
# marks        72
# Name: 1, dtype: object

# %%
df.loc[1]
# Out:
# name     Bivhas
# age          20
# marks        72
# Name: 1, dtype: object

# %%
df.loc[0,'name']
# Out:
# 'Dinesh'

# %%
df[df['marks']>80]
# Out:
#      name  age  marks
# 3  Sudeep   25     90

# %%
df[(df['age']>20)&(df['marks']>70)]
# Out:
#      name  age  marks
# 2  Jikmet   21     80
# 3  Sudeep   25     90
# 4  Sworup   23     75
# 5  Sangat   32     73

# %%
# add grade column to df
df['Grade']=['B','B','A','B','B','B']

# %%
print(df)
# Out:
#      name  age  marks Grade
# 0  Dinesh   22     70     B
# 1  Bivhas   20     72     B
# 2  Jikmet   21     80     A
# 3  Sudeep   25     90     B
# 4  Sworup   23     75     B
# 5  Sangat   32     73     B

# %%
#Add marks of all by 5
df['marks']=df['marks']+5

# %%
#Change Marks
df.loc[df['name']=='Dinesh','marks']=80

# %%
#Remove age column
df.drop('age',axis=1)
# Out:
#      name  marks Grade
# 0  Dinesh     80     B
# 1  Bivhas     85     B
# 2  Jikmet     85     A
# 3  Sudeep     95     B
# 4  Sworup     80     B
# 5  Sangat     78     B

# %%
#Remove 1st row of te dataframe
df.drop(0,axis=0)
# Out:
#      name  age  marks Grade
# 1  Bivhas   20     85     B
# 2  Jikmet   21     85     A
# 3  Sudeep   25     95     B
# 4  Sworup   23     80     B
# 5  Sangat   32     78     B

# %%
#arranging values (marks) in ascending order
df.sort_values('marks')
# Out:
#      name  age  marks Grade
# 5  Sangat   32     78     B
# 0  Dinesh   22     80     B
# 4  Sworup   23     80     B
# 1  Bivhas   20     85     B
# 2  Jikmet   21     85     A
# 3  Sudeep   25     95     B

# %%
#arranging values (marks) in descending order
df.sort_values('marks',ascending=False)
# Out:
#      name  age  marks Grade
# 3  Sudeep   25     95     B
# 1  Bivhas   20     85     B
# 2  Jikmet   21     85     A
# 0  Dinesh   22     80     B
# 4  Sworup   23     80     B
# 5  Sangat   32     78     B

# %%
c={
    "name":["Gautam","Dindayal","Dikshant","Hari","Ashim","Avash"],
    "age":[22,20,21,25,23,32],
    "marks":[70,72,80,90,75,73]
}
df1=pd.DataFrame(c)

# %%
pd.concat([df1,df])
# Out:
#        name  age  marks Grade
# 0    Gautam   22     70   NaN
# 1  Dindayal   20     72   NaN
# 2  Dikshant   21     80   NaN
# 3      Hari   25     90   NaN
# 4     Ashim   23     75   NaN
# 5     Avash   32     73   NaN
# 0    Dinesh   22     80     B
# 1    Bivhas   20     85     B
# 2    Jikmet   21     85     A
# 3    Sudeep   25     95     B
# 4    Sworup   23     80     B
# 5    Sangat   32     78     B

# %%
df.to_csv('file.csv')

# %%
pd.read_excel('file.xlsx')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                 Budget Spreadsheet
# 5          NaN  Thank you for using our spreadsheet! Let's gui...
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                           We also have a free app!
# 9          NaN  The app does everything this spreadsheet does ...
# 10         NaN                                                NaN
# ...

# %%
df.to_excel('file.xlsx')
